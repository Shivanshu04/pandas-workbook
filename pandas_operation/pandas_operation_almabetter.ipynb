# %%
import numpy as np 
import pandas as pd

# %%
a=np.random.randint(10,20, size=(4,6))
a
# Out:
# array([[13, 14, 16, 15, 11, 19],
#        [14, 10, 17, 10, 14, 11],
#        [15, 13, 17, 14, 11, 11],
#        [17, 15, 13, 14, 18, 18]])

# %%
a[1,1]
# Out:
# 10

# %%
a[1][1]
# Out:
# 10

# %%
a_df=pd.DataFrame(a,columns=['a','c','b','d','e','f'],index=['x','y','e','h'])
a_df
# Out:
#     a   c   b   d   e   f
# x  13  14  16  15  11  19
# y  14  10  17  10  14  11
# e  15  13  17  14  11  11
# h  17  15  13  14  18  18

# %%
a_df.iloc[1,1]
# Out:
# 10

# %%
a_df.loc['x']
# Out:
# a    13
# c    14
# b    16
# d    15
# e    11
# f    19
# Name: x, dtype: int32

# %%
a_df.loc["x","c"]
# Out:
# 14

# %%
# acess only f column
a_df.loc[:,"f"]
# Out:
# x    19
# y    11
# e    11
# h    18
# Name: f, dtype: int32

# %%
a_df.iloc[:,[5,0]] #iloc use for indeger index and loc use for   char index
# Out:
#     f   a
# x  19  13
# y  11  14
# e  11  15
# h  18  17

# %%
df=pd.read_csv("movies.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5d7cecf54ca0> in <module>
# ----> 1 df=pd.read_csv("movies.csv")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.shape
# Out:
# (50000, 2)
