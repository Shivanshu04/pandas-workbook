# %%
import numpy as np

# %% [markdown]
# np.flatten functiom

# %%
random_3d =np.array(np.random.randint(10,45,(2,4,6)))
print(f"The defined array is \n{random_3d}")
print(f"The shape of array is {random_3d.shape}")
# Out:
# The defined array is
# [[[15 15 34 13 34 38]
#   [11 22 42 40 34 28]
#   [15 22 14 17 10 13]
#   [41 37 10 34 16 40]]
#
#  [[32 18 11 15 30 34]
#   [37 12 18 35 21 15]
#   [40 14 12 31 28 26]
#   [16 33 20 34 21 28]]]
# The shape of array is (2, 4, 6)

# %%
#flatten The 3d array
random_3d.flatten()
# Out:
# array([15, 15, 34, 13, 34, 38, 11, 22, 42, 40, 34, 28, 15, 22, 14, 17, 10,
#        13, 41, 37, 10, 34, 16, 40, 32, 18, 11, 15, 30, 34, 37, 12, 18, 35,
#        21, 15, 40, 14, 12, 31, 28, 26, 16, 33, 20, 34, 21, 28])

# %% [markdown]
# pandas is python package providing flexible

# %%
import pandas as pd

# %%
#our first series
number_series =pd.Series([1,2,4,5,6])
print(number_series)
# Out:
# 0    1
# 1    2
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
# same series buth with different indices
number_series =pd.Series([1,2,4,5,6],index=['a','b','c','d','e'],name='Number')
print(number_series)
# Out:
# a    1
# b    2
# c    4
# d    5
# e    6
# Name: Number, dtype: int64

# %%
# indexing
print(number_series[0])
print(number_series['c'])
# Out:
# 1
# 4

# %%
#creating our data frame usinh 2-D numpy array
some_2d_array =np.random.randint(4,10 ,(2,3))  #2-D numpy array(2=rows,3=column)
print(some_2d_array)
first_datafame = pd.DataFrame(some_2d_array,columns=["Akshay","Shiv","aman"])
print(first_datafame)
# Out:
# [[7 4 7]
#  [7 4 7]]
#    Akshay  Shiv  aman
# 0       7     4     7
# 1       7     4     7

# %%
#creating our data frame usinh 2-D numpy array
some_2d_array =np.random.randint(4,10 ,(4,3))  #2-D numpy array
first_datafame = pd.DataFrame(some_2d_array,columns=["Akshay","Shiv","Koko"])
print(first_datafame)
# Out:
#    Akshay  Shiv  Koko
# 0       7     4     4
# 1       5     5     8
# 2       5     4     4
# 3       4     7     6

# %%
first_datafame.loc['Akshay']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-4ff517438673> in <module>
# ----> 1 first_datafame.loc['Akshay']
#
# e:\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# e:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# e:\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# e:\Anaconda\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# e:\Anaconda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# KeyError: 'Akshay'
